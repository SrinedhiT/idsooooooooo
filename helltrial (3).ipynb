# %%
#Importing necessary dependencies
import numpy as np
import pandas as pd
import sklearn.metrics
import sklearn.model_selection
import sklearn.linear_model
import sklearn.preprocessing
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import optimizers
from tensorflow.keras.models import Model, load_model, Sequential
from tensorflow.keras.layers import Input, Dense, Dropout, AlphaDropout
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, precision_recall_curve
from sklearn.metrics import recall_score, classification_report, auc, roc_curve
from sklearn.metrics import precision_recall_fscore_support, f1_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV
from numpy import dstack
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import confusion_matrix
from sklearn import metrics

# %%
#Loading dataset
d1 = pd.read_csv('/content/UNSW_NB15_training-set.csv')
t1 = pd.read_csv('/content/UNSW_NB15_testing-set.csv')

# %%
data = d1.append(t1, ignore_index = True)

# %%
data
# Out:
#             id       dur proto service state  spkts  dpkts  sbytes  dbytes  \
# 0            1  0.000011   udp       -   INT      2      0     496       0
# 1            2  0.000008   udp       -   INT      2      0    1762       0
# 2            3  0.000005   udp       -   INT      2      0    1068       0
# 3            4  0.000006   udp       -   INT      2      0     900       0
# 4            5  0.000010   udp       -   INT      2      0    2126       0
# ...        ...       ...   ...     ...   ...    ...    ...     ...     ...
# 257668  175337  0.000009   udp     dns   INT      2      0     114       0
# 257669  175338  0.505762   tcp       -   FIN     10      8     620     354
# 257670  175339  0.000009   udp     dns   INT      2      0     114       0
# 257671  175340  0.000009   udp     dns   INT      2      0     114       0
# 257672  175341  0.000009   udp     dns   INT      2      0     114       0
#
#                  rate  ...  ct_dst_sport_ltm  ct_dst_src_ltm  is_ftp_login  \
# 0        90909.090200  ...                 1               2             0
# 1       125000.000300  ...                 1               2             0
# 2       200000.005100  ...                 1               3             0
# 3       166666.660800  ...                 1               3             0
# 4       100000.002500  ...                 1               3             0
# ...               ...  ...               ...             ...           ...
# 257668  111111.107200  ...                13              24             0
# 257669      33.612649  ...                 1               2             0
# 257670  111111.107200  ...                 3              13             0
# 257671  111111.107200  ...                14              30             0
# 257672  111111.107200  ...                16              30             0
#
#         ct_ftp_cmd  ct_flw_http_mthd  ct_src_ltm  ct_srv_dst  is_sm_ips_ports  \
# 0                0                 0           1           2                0
# 1                0                 0           1           2                0
# 2                0                 0           1           3                0
# 3                0                 0           2           3                0
# 4                0                 0           2           3                0
# ...            ...               ...         ...         ...              ...
# 257668           0                 0          24          24                0
# 257669           0                 0           1           1                0
# 257670           0                 0           3          12                0
# 257671           0                 0          30          30                0
# 257672           0                 0          30          30                0
#
#         attack_cat  label
# 0           Normal      0
# 1           Normal      0
# 2           Normal      0
# 3           Normal      0
# 4           Normal      0
# ...            ...    ...
# 257668     Generic      1
# 257669   Shellcode      1
# 257670     Generic      1
# 257671     Generic      1
# 257672     Generic      1
#
# [257673 rows x 45 columns]

# %%
from sklearn import preprocessing
data.drop(columns = 'label', inplace = True)
multic = pd.DataFrame(data.attack_cat)
le2 = preprocessing.LabelEncoder()
enc_label = multic.apply(le2.fit_transform)
data['attax'] = enc_label

# %%
data
# Out:
#             id       dur proto service state  spkts  dpkts  sbytes  dbytes  \
# 0            1  0.000011   udp       -   INT      2      0     496       0
# 1            2  0.000008   udp       -   INT      2      0    1762       0
# 2            3  0.000005   udp       -   INT      2      0    1068       0
# 3            4  0.000006   udp       -   INT      2      0     900       0
# 4            5  0.000010   udp       -   INT      2      0    2126       0
# ...        ...       ...   ...     ...   ...    ...    ...     ...     ...
# 257668  175337  0.000009   udp     dns   INT      2      0     114       0
# 257669  175338  0.505762   tcp       -   FIN     10      8     620     354
# 257670  175339  0.000009   udp     dns   INT      2      0     114       0
# 257671  175340  0.000009   udp     dns   INT      2      0     114       0
# 257672  175341  0.000009   udp     dns   INT      2      0     114       0
#
#                  rate  ...  ct_dst_sport_ltm  ct_dst_src_ltm  is_ftp_login  \
# 0        90909.090200  ...                 1               2             0
# 1       125000.000300  ...                 1               2             0
# 2       200000.005100  ...                 1               3             0
# 3       166666.660800  ...                 1               3             0
# 4       100000.002500  ...                 1               3             0
# ...               ...  ...               ...             ...           ...
# 257668  111111.107200  ...                13              24             0
# 257669      33.612649  ...                 1               2             0
# 257670  111111.107200  ...                 3              13             0
# 257671  111111.107200  ...                14              30             0
# 257672  111111.107200  ...                16              30             0
#
#         ct_ftp_cmd  ct_flw_http_mthd  ct_src_ltm  ct_srv_dst  is_sm_ips_ports  \
# 0                0                 0           1           2                0
# 1                0                 0           1           2                0
# 2                0                 0           1           3                0
# 3                0                 0           2           3                0
# 4                0                 0           2           3                0
# ...            ...               ...         ...         ...              ...
# 257668           0                 0          24          24                0
# 257669           0                 0           1           1                0
# 257670           0                 0           3          12                0
# 257671           0                 0          30          30                0
# 257672           0                 0          30          30                0
#
#         attack_cat  attax
# 0           Normal      6
# 1           Normal      6
# 2           Normal      6
# 3           Normal      6
# 4           Normal      6
# ...            ...    ...
# 257668     Generic      5
# 257669   Shellcode      8
# 257670     Generic      5
# 257671     Generic      5
# 257672     Generic      5
#
# [257673 rows x 45 columns]

# %%
categorical_features = ['proto', 'service', 'state']
label_feature = ['attack_cat', 'attax']

# %%
drop_features = ['id', 'sttl', 'dttl', 'swin', 'dwin', 'trans_depth', 'response_body_len', 'ct_srv_src', 'ct_state_ttl', 'ct_dst_ltm', 'ct_src_dport_ltm', 'ct_dst_sport_ltm', 'ct_dst_src_ltm', 'is_ftp_login', 'ct_ftp_cmd', 'ct_flw_http_mthd', 'ct_src_ltm', 'ct_srv_dst', 'is_sm_ips_ports']
numerical_features = list(set(data.columns) - set(label_feature) - set(categorical_features) - set(drop_features))

# %%
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()

# %%
data.drop(columns = categorical_features, inplace = True)

# %%
data
# Out:
#             id       dur  spkts  dpkts  sbytes  dbytes           rate  sttl  \
# 0            1  0.000011      2      0     496       0   90909.090200   254
# 1            2  0.000008      2      0    1762       0  125000.000300   254
# 2            3  0.000005      2      0    1068       0  200000.005100   254
# 3            4  0.000006      2      0     900       0  166666.660800   254
# 4            5  0.000010      2      0    2126       0  100000.002500   254
# ...        ...       ...    ...    ...     ...     ...            ...   ...
# 257668  175337  0.000009      2      0     114       0  111111.107200   254
# 257669  175338  0.505762     10      8     620     354      33.612649   254
# 257670  175339  0.000009      2      0     114       0  111111.107200   254
# 257671  175340  0.000009      2      0     114       0  111111.107200   254
# 257672  175341  0.000009      2      0     114       0  111111.107200   254
#
#         dttl         sload  ...  ct_dst_sport_ltm  ct_dst_src_ltm  \
# 0          0  1.803636e+08  ...                 1               2
# 1          0  8.810000e+08  ...                 1               2
# 2          0  8.544000e+08  ...                 1               3
# 3          0  6.000000e+08  ...                 1               3
# 4          0  8.504000e+08  ...                 1               3
# ...      ...           ...  ...               ...             ...
# 257668     0  5.066666e+07  ...                13              24
# 257669   252  8.826286e+03  ...                 1               2
# 257670     0  5.066666e+07  ...                 3              13
# 257671     0  5.066666e+07  ...                14              30
# 257672     0  5.066666e+07  ...                16              30
#
#         is_ftp_login  ct_ftp_cmd  ct_flw_http_mthd  ct_src_ltm  ct_srv_dst  \
# 0                  0           0                 0           1           2
# 1                  0           0                 0           1           2
# 2                  0           0                 0           1           3
# 3                  0           0                 0           2           3
# 4                  0           0                 0           2           3
# ...              ...         ...               ...         ...         ...
# 257668             0           0                 0          24          24
# 257669             0           0                 0           1           1
# 257670             0           0                 0           3          12
# 257671             0           0                 0          30          30
# 257672             0           0                 0          30          30
#
#         is_sm_ips_ports  attack_cat  attax
# 0                     0      Normal      6
# 1                     0      Normal      6
# 2                     0      Normal      6
# 3                     0      Normal      6
# 4                     0      Normal      6
# ...                 ...         ...    ...
# 257668                0     Generic      5
# 257669                0   Shellcode      8
# 257670                0     Generic      5
# 257671                0     Generic      5
# 257672                0     Generic      5
#
# [257673 rows x 42 columns]

# %%
data.dropna(inplace=True)

# %%
data.reset_index(drop=True, inplace=True)

# %%
Y = data['attax']
X = data.drop(columns = ['attax', 'attack_cat'], axis = 1)

# %%
pip install tab2img
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tab2img
#   Downloading tab2img-0.0.2-py3-none-any.whl (4.8 kB)
# Installing collected packages: tab2img
# Successfully installed tab2img-0.0.2

# %%
from tab2img.converter import Tab2Img

# %%
scaler = preprocessing.MinMaxScaler().fit(X)
X_scaled_train = scaler.transform(X)
y_scaler =  preprocessing.StandardScaler().fit(Y.values.reshape(-1, 1))
y_scaled_train = y_scaler.transform(Y.values.reshape(-1, 1))

# %%
model = Tab2Img()
#train_images = model.fit_transform(X, Y)

# %%
train_images = model.fit_transform(X_scaled_train, y_scaled_train)

# %%
from PIL import Image
fig,ax = plt.subplots(2,5)
for i in range(10):
    nparray = train_images[i]
    image = Image.fromarray(nparray * 255)
    ax[i%2][i//2].imshow(image)
fig.show()

# %%
train_images
# Out:
# array([[[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 9.09090936e-02],
#         [0.00000000e+00, 0.00000000e+00, 1.61290318e-02, ...,
#          0.00000000e+00, 0.00000000e+00, 9.96078432e-01],
#         [0.00000000e+00, 0.00000000e+00, 1.30375781e-07, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         ...,
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 1.83333370e-07, 0.00000000e+00],
#         [0.00000000e+00, 3.28788119e-05, 0.00000000e+00, ...,
#          3.01208459e-02, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 3.33333343e-01, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#        [[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 1.25000000e-01],
#         [0.00000000e+00, 0.00000000e+00, 1.61290318e-02, ...,
#          0.00000000e+00, 0.00000000e+00, 9.96078432e-01],
#         [0.00000000e+00, 0.00000000e+00, 9.48187520e-08, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         ...,
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 1.33333359e-07, 0.00000000e+00],
#         [0.00000000e+00, 1.21066470e-04, 0.00000000e+00, ...,
#          1.47127584e-01, 0.00000000e+00, 0.00000000e+00],
#         [5.70320526e-06, 3.33333343e-01, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#        [[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 2.00000003e-01],
#         [0.00000000e+00, 0.00000000e+00, 3.22580636e-02, ...,
#          0.00000000e+00, 0.00000000e+00, 9.96078432e-01],
#         [0.00000000e+00, 0.00000000e+00, 5.92617191e-08, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         ...,
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 8.33333473e-08, 0.00000000e+00],
#         [0.00000000e+00, 7.27234728e-05, 0.00000000e+00, ...,
#          1.42685369e-01, 0.00000000e+00, 0.00000000e+00],
#         [1.14064105e-05, 3.33333343e-01, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#        ...,
#
#        [[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 1.11111104e-01],
#         [0.00000000e+00, 0.00000000e+00, 1.77419350e-01, ...,
#          0.00000000e+00, 0.00000000e+00, 9.96078432e-01],
#         [0.00000000e+00, 3.44827585e-02, 1.06671095e-07, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         ...,
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 1.50000034e-07, 0.00000000e+00],
#         [0.00000000e+00, 6.26926476e-06, 0.00000000e+00, ...,
#          8.46136641e-03, 0.00000000e+00, 0.00000000e+00],
#         [9.99988616e-01, 3.33333343e-01, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#        [[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 1.11111104e-01],
#         [0.00000000e+00, 0.00000000e+00, 4.67741936e-01, ...,
#          0.00000000e+00, 0.00000000e+00, 9.96078432e-01],
#         [0.00000000e+00, 5.00000000e-01, 1.06671095e-07, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         ...,
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 1.50000034e-07, 0.00000000e+00],
#         [0.00000000e+00, 6.26926476e-06, 0.00000000e+00, ...,
#          8.46136641e-03, 0.00000000e+00, 0.00000000e+00],
#         [9.99994278e-01, 3.33333343e-01, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#        [[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 1.11111104e-01],
#         [0.00000000e+00, 0.00000000e+00, 4.67741936e-01, ...,
#          0.00000000e+00, 0.00000000e+00, 9.96078432e-01],
#         [0.00000000e+00, 5.00000000e-01, 1.06671095e-07, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         ...,
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 1.50000034e-07, 0.00000000e+00],
#         [0.00000000e+00, 6.26926476e-06, 0.00000000e+00, ...,
#          8.46136641e-03, 0.00000000e+00, 0.00000000e+00],
#         [1.00000000e+00, 3.33333343e-01, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00]]], dtype=float32)

# %%
from matplotlib import pyplot as plt
for i in range(5):
    plt.imshow(train_images[i], interpolation='nearest')
    plt.show()

# %%
from tensorflow.keras import Model, optimizers
from tensorflow.keras import Sequential
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Conv2D, Input, Dropout, Activation, Dense, MaxPooling2D, Flatten, GlobalAveragePooling2D
import sklearn
from sklearn.model_selection import train_test_split

# %%
new_shape = (train_images.shape[0], train_images.shape[1], train_images.shape[2], 1)
Y = tf.keras.utils.to_categorical(Y)
train_images = train_images.reshape(new_shape)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(train_images, Y, random_state=10, test_size=0.2)

# %%
print(X_train.shape, Y_train.shape)
print(X_test.shape, Y_test.shape)
# Out:
# (206138, 7, 7, 1) (206138, 10)
# (51535, 7, 7, 1) (51535, 10)

# %%
input_shape = (7,7,1)
num_classes = 10

# %%
#Evaluation Metrics for the Multilayer Perceptrons
class FalsePositiveRate(tf.keras.metrics.Metric):
    def __init__(self, name='false_positive_rate', **kwargs):
        super(FalsePositiveRate, self).__init__(name=name, **kwargs)
        self.negatives = self.add_weight(name='negatives', initializer='zeros')
        self.false_positives = self.add_weight(name='false_negatives', initializer='zeros')
        
    def update_state(self, y_true, y_pred, sample_weight=None):
        y_true = tf.cast(y_true, tf.bool)
        
        negatives = tf.reduce_sum(tf.cast(tf.equal(y_true, False), self.dtype))
        
        self.negatives.assign_add(negatives)
        
        y_pred = tf.greater_equal(y_pred, 0.5)
        
        false_positive_values = tf.logical_and(tf.equal(y_true, False), tf.equal(y_pred, True)) 
        false_positive_values = tf.cast(false_positive_values, self.dtype)
        if sample_weight is not None:
            sample_weight = tf.cast(sample_weight, self.dtype)
            sample_weight = tf.broadcast_weights(sample_weight, values)
            values = tf.multiply(false_positive_values, sample_weight)
        
        false_positives = tf.reduce_sum(false_positive_values)
        
        self.false_positives.assign_add(false_positives)
        
    def result(self):
        return tf.divide(self.false_positives, self.negatives)

# %%
#Evaluation Metrics for the Multilayer Perceptrons
def plot_loss(model_history):
  train_loss=[value for key, value in model_history.items() if 'loss' in key.lower()][0]
  valid_loss=[value for key, value in model_history.items() if 'loss' in key.lower()][1]
  fig, ax1 = plt.subplots()
  color = 'tab:blue'
  ax1.set_xlabel('Epoch')
  ax1.set_ylabel('Loss', color=color)
  ax1.plot(train_loss, '--', color=color, label='Train Loss')
  ax1.plot(valid_loss, color=color, label='Valid Loss')
  ax1.tick_params(axis='y', labelcolor=color)
  plt.legend(loc='upper left')
  plt.title('Model Loss')
  plt.show()

# %%
#Evaluation Metrics
def plot_model_recall_fpr(model_history):
  train_recall=[value for key, value in model_history.items() if 'recall' in key.lower()][0]
  valid_recall=[value for key, value in model_history.items() if 'recall' in key.lower()][1]
  train_fpr=[value for key, value in model_history.items() if 'false_positive_rate' in key.lower()][0]
  valid_fpr=[value for key, value in model_history.items() if 'false_positive_rate' in key.lower()][1]
  fig, ax1 = plt.subplots()
  color = 'tab:red'
  ax1.set_xlabel('Epoch')
  ax1.set_ylabel('Recall', color=color)
  ax1.set_ylim([-0.05,1.05])
  ax1.plot(train_recall, '--', color=color, label='Train Recall')
  ax1.plot(valid_recall, color=color, label='Valid Recall')
  ax1.tick_params(axis='y', labelcolor=color)
  plt.legend(loc='upper left')
  plt.title('Model Recall and FPR')
  ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
  color = 'tab:blue'
  ax2.set_ylabel('False Positive Rate', color=color)  # we already handled the x-label with ax1
  ax2.plot(valid_fpr, color=color, label='Valid FPR')
  ax2.tick_params(axis='y', labelcolor=color)
  ax2.set_ylim([-0.05,1.05])
  fig.tight_layout()  # otherwise the right y-label is slightly clipped
  plt.legend(loc='upper right')
  plt.show()

# %%
#Evaluation Metrics
def plot_train_history(history):
    # plot the cost and accuracy 
    loss_list = history['loss']
    val_loss_list = history['val_loss']
    accuracy_list = history['accuracy']
    val_accuracy_list = history['val_accuracy']
    # epochs = range(len(loss_list))

    # plot the cost
    plt.plot(loss_list, 'b', label='Training cost')
    plt.plot(val_loss_list, 'r', label='Validation cost')
    plt.ylabel('cost')
    plt.xlabel('iterations')
    plt.title('Training and validation cost')
    plt.legend()

    plt.figure()
    
    # plot the accuracy
    plt.plot(accuracy_list, 'b', label='Training accuracy')
    plt.plot(val_accuracy_list, 'r', label='Validation accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('iterations')
    plt.title('Training and validation accuracy')
    plt.legend()

# %%
train_images.shape
# Out:
# (257673, 7, 7, 1)

# %%
Y.shape
# Out:
# (257673, 10)

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), padding='same', activation='relu',
                 input_shape=input_shape))

model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))

model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Dropout(0.2))

model.add(Flatten())

model.add(Dense(256, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))
model.compile(optimizers.Adam(learning_rate=0.001),loss="categorical_crossentropy",metrics=['accuracy', FalsePositiveRate(), tf.keras.metrics.Recall()])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 7, 7, 32)          320
#
#  conv2d_1 (Conv2D)           (None, 7, 7, 64)          18496
#
#  conv2d_2 (Conv2D)           (None, 7, 7, 128)         73856
#
#  max_pooling2d (MaxPooling2D  (None, 3, 3, 128)        0
#  )
#
#  dropout (Dropout)           (None, 3, 3, 128)         0
#
#  flatten (Flatten)           (None, 1152)              0
#
#  dense (Dense)               (None, 256)               295168
#
#  dense_1 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 390,410
# Trainable params: 390,410
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x=train_images, y=Y, batch_size=1000, epochs = 100, validation_split = 0.2, verbose=1).history
# Out:
# Epoch 1/100
# 207/207 [==============================] - 171s 816ms/step - loss: 0.9926 - accuracy: 0.6323 - false_positive_rate: 0.0080 - recall: 0.4630 - val_loss: 0.5925 - val_accuracy: 0.8258 - val_false_positive_rate: 0.0039 - val_recall: 0.7237
# Epoch 2/100
# 207/207 [==============================] - 145s 699ms/step - loss: 0.6770 - accuracy: 0.7438 - false_positive_rate: 0.0101 - recall: 0.6251 - val_loss: 0.4003 - val_accuracy: 0.8738 - val_false_positive_rate: 0.0046 - val_recall: 0.8300
# Epoch 3/100
# 207/207 [==============================] - 145s 703ms/step - loss: 0.6066 - accuracy: 0.7690 - false_positive_rate: 0.0109 - recall: 0.6740 - val_loss: 0.3853 - val_accuracy: 0.8774 - val_false_positive_rate: 0.0047 - val_recall: 0.8335
# Epoch 4/100
# 207/207 [==============================] - 145s 701ms/step - loss: 0.5767 - accuracy: 0.7802 - false_positive_rate: 0.0109 - recall: 0.6946 - val_loss: 0.3738 - val_accuracy: 0.8844 - val_false_positive_rate: 0.0050 - val_recall: 0.8450
# Epoch 5/100
# 207/207 [==============================] - 145s 701ms/step - loss: 0.5587 - accuracy: 0.7871 - false_positive_rate: 0.0106 - recall: 0.7032 - val_loss: 0.3521 - val_accuracy: 0.8892 - val_false_positive_rate: 0.0044 - val_recall: 0.8457
# Epoch 6/100
# 207/207 [==============================] - 145s 698ms/step - loss: 0.5421 - accuracy: 0.7932 - false_positive_rate: 0.0105 - recall: 0.7131 - val_loss: 0.3487 - val_accuracy: 0.8902 - val_false_positive_rate: 0.0041 - val_recall: 0.8472
# Epoch 7/100
# 207/207 [==============================] - 144s 697ms/step - loss: 0.5256 - accuracy: 0.7997 - false_positive_rate: 0.0100 - recall: 0.7204 - val_loss: 0.3393 - val_accuracy: 0.8908 - val_false_positive_rate: 0.0043 - val_recall: 0.8494
# Epoch 8/100
# 207/207 [==============================] - 145s 702ms/step - loss: 0.5084 - accuracy: 0.8068 - false_positive_rate: 0.0097 - recall: 0.7294 - val_loss: 0.3263 - val_accuracy: 0.8890 - val_false_positive_rate: 0.0041 - val_recall: 0.8503
# Epoch 9/100
# 207/207 [==============================] - 146s 704ms/step - loss: 0.4973 - accuracy: 0.8113 - false_positive_rate: 0.0094 - recall: 0.7349 - val_loss: 0.3255 - val_accuracy: 0.8904 - val_false_positive_rate: 0.0040 - val_recall: 0.8518
# Epoch 10/100
# 207/207 [==============================] - 145s 701ms/step - loss: 0.4884 - accuracy: 0.8138 - false_positive_rate: 0.0093 - recall: 0.7405 - val_loss: 0.3164 - val_accuracy: 0.8925 - val_false_positive_rate: 0.0042 - val_recall: 0.8538
# Epoch 11/100
# 207/207 [==============================] - 144s 696ms/step - loss: 0.4786 - accuracy: 0.8171 - false_positive_rate: 0.0089 - recall: 0.7428 - val_loss: 0.3209 - val_accuracy: 0.8904 - val_false_positive_rate: 0.0046 - val_recall: 0.8572
# Epoch 12/100
# 207/207 [==============================] - 145s 700ms/step - loss: 0.4706 - accuracy: 0.8195 - false_positive_rate: 0.0090 - recall: 0.7482 - val_loss: 0.3161 - val_accuracy: 0.8901 - val_false_positive_rate: 0.0043 - val_recall: 0.8547
# Epoch 13/100
# 207/207 [==============================] - 145s 699ms/step - loss: 0.4631 - accuracy: 0.8214 - false_positive_rate: 0.0089 - recall: 0.7509 - val_loss: 0.3142 - val_accuracy: 0.8939 - val_false_positive_rate: 0.0035 - val_recall: 0.8493
# Epoch 14/100
# 207/207 [==============================] - 144s 697ms/step - loss: 0.4570 - accuracy: 0.8232 - false_positive_rate: 0.0087 - recall: 0.7539 - val_loss: 0.3105 - val_accuracy: 0.8948 - val_false_positive_rate: 0.0037 - val_recall: 0.8537
# Epoch 15/100
# 207/207 [==============================] - 144s 696ms/step - loss: 0.4504 - accuracy: 0.8257 - false_positive_rate: 0.0086 - recall: 0.7571 - val_loss: 0.3002 - val_accuracy: 0.8932 - val_false_positive_rate: 0.0042 - val_recall: 0.8598
# Epoch 16/100
# 207/207 [==============================] - 144s 697ms/step - loss: 0.4448 - accuracy: 0.8285 - false_positive_rate: 0.0084 - recall: 0.7599 - val_loss: 0.2991 - val_accuracy: 0.8967 - val_false_positive_rate: 0.0037 - val_recall: 0.8571
# Epoch 17/100
# 207/207 [==============================] - 144s 695ms/step - loss: 0.4411 - accuracy: 0.8288 - false_positive_rate: 0.0084 - recall: 0.7612 - val_loss: 0.3043 - val_accuracy: 0.8934 - val_false_positive_rate: 0.0039 - val_recall: 0.8593
# Epoch 18/100
# 207/207 [==============================] - 145s 702ms/step - loss: 0.4361 - accuracy: 0.8312 - false_positive_rate: 0.0084 - recall: 0.7636 - val_loss: 0.2942 - val_accuracy: 0.8967 - val_false_positive_rate: 0.0038 - val_recall: 0.8569
# Epoch 19/100
# 207/207 [==============================] - 144s 696ms/step - loss: 0.4323 - accuracy: 0.8317 - false_positive_rate: 0.0084 - recall: 0.7659 - val_loss: 0.2985 - val_accuracy: 0.8935 - val_false_positive_rate: 0.0042 - val_recall: 0.8602
# Epoch 20/100
# 207/207 [==============================] - 145s 698ms/step - loss: 0.4294 - accuracy: 0.8326 - false_positive_rate: 0.0083 - recall: 0.7663 - val_loss: 0.2898 - val_accuracy: 0.8970 - val_false_positive_rate: 0.0041 - val_recall: 0.8597
# Epoch 21/100
# 207/207 [==============================] - 144s 695ms/step - loss: 0.4245 - accuracy: 0.8342 - false_positive_rate: 0.0082 - recall: 0.7677 - val_loss: 0.2970 - val_accuracy: 0.8966 - val_false_positive_rate: 0.0043 - val_recall: 0.8592
# Epoch 22/100
# 207/207 [==============================] - 145s 698ms/step - loss: 0.4229 - accuracy: 0.8355 - false_positive_rate: 0.0083 - recall: 0.7704 - val_loss: 0.2909 - val_accuracy: 0.8988 - val_false_positive_rate: 0.0036 - val_recall: 0.8598
# Epoch 23/100
# 207/207 [==============================] - 144s 696ms/step - loss: 0.4190 - accuracy: 0.8357 - false_positive_rate: 0.0082 - recall: 0.7714 - val_loss: 0.2844 - val_accuracy: 0.8996 - val_false_positive_rate: 0.0036 - val_recall: 0.8606
# Epoch 24/100
# 207/207 [==============================] - 144s 696ms/step - loss: 0.4148 - accuracy: 0.8380 - false_positive_rate: 0.0080 - recall: 0.7735 - val_loss: 0.2933 - val_accuracy: 0.8976 - val_false_positive_rate: 0.0044 - val_recall: 0.8614
# Epoch 25/100
# 207/207 [==============================] - 144s 694ms/step - loss: 0.4134 - accuracy: 0.8383 - false_positive_rate: 0.0080 - recall: 0.7739 - val_loss: 0.2874 - val_accuracy: 0.8991 - val_false_positive_rate: 0.0038 - val_recall: 0.8612
# Epoch 26/100
# 207/207 [==============================] - 142s 688ms/step - loss: 0.4126 - accuracy: 0.8384 - false_positive_rate: 0.0082 - recall: 0.7752 - val_loss: 0.2995 - val_accuracy: 0.8923 - val_false_positive_rate: 0.0050 - val_recall: 0.8591
# Epoch 27/100
# 207/207 [==============================] - 143s 690ms/step - loss: 0.4076 - accuracy: 0.8405 - false_positive_rate: 0.0080 - recall: 0.7773 - val_loss: 0.2823 - val_accuracy: 0.8981 - val_false_positive_rate: 0.0041 - val_recall: 0.8626
# Epoch 28/100
# 207/207 [==============================] - 144s 698ms/step - loss: 0.4064 - accuracy: 0.8406 - false_positive_rate: 0.0080 - recall: 0.7778 - val_loss: 0.2835 - val_accuracy: 0.8984 - val_false_positive_rate: 0.0039 - val_recall: 0.8601
# Epoch 29/100
# 207/207 [==============================] - 145s 699ms/step - loss: 0.4050 - accuracy: 0.8414 - false_positive_rate: 0.0079 - recall: 0.7786 - val_loss: 0.2904 - val_accuracy: 0.8986 - val_false_positive_rate: 0.0045 - val_recall: 0.8625
# Epoch 30/100
# 207/207 [==============================] - 144s 695ms/step - loss: 0.4047 - accuracy: 0.8414 - false_positive_rate: 0.0079 - recall: 0.7778 - val_loss: 0.2906 - val_accuracy: 0.8986 - val_false_positive_rate: 0.0046 - val_recall: 0.8628
# Epoch 31/100
# 207/207 [==============================] - 144s 697ms/step - loss: 0.4010 - accuracy: 0.8428 - false_positive_rate: 0.0080 - recall: 0.7807 - val_loss: 0.2838 - val_accuracy: 0.8992 - val_false_positive_rate: 0.0038 - val_recall: 0.8623
# Epoch 32/100
# 207/207 [==============================] - 144s 696ms/step - loss: 0.3987 - accuracy: 0.8430 - false_positive_rate: 0.0078 - recall: 0.7815 - val_loss: 0.2855 - val_accuracy: 0.8984 - val_false_positive_rate: 0.0041 - val_recall: 0.8609
# Epoch 33/100
# 207/207 [==============================] - 144s 696ms/step - loss: 0.3958 - accuracy: 0.8443 - false_positive_rate: 0.0079 - recall: 0.7844 - val_loss: 0.2780 - val_accuracy: 0.8998 - val_false_positive_rate: 0.0041 - val_recall: 0.8620
# Epoch 34/100
# 207/207 [==============================] - 144s 698ms/step - loss: 0.3955 - accuracy: 0.8439 - false_positive_rate: 0.0079 - recall: 0.7829 - val_loss: 0.2878 - val_accuracy: 0.8988 - val_false_positive_rate: 0.0043 - val_recall: 0.8621
# Epoch 35/100
# 207/207 [==============================] - 144s 698ms/step - loss: 0.3948 - accuracy: 0.8444 - false_positive_rate: 0.0077 - recall: 0.7828 - val_loss: 0.2802 - val_accuracy: 0.9003 - val_false_positive_rate: 0.0041 - val_recall: 0.8634
# Epoch 36/100
# 207/207 [==============================] - 144s 697ms/step - loss: 0.3910 - accuracy: 0.8454 - false_positive_rate: 0.0078 - recall: 0.7849 - val_loss: 0.2796 - val_accuracy: 0.9006 - val_false_positive_rate: 0.0044 - val_recall: 0.8648
# Epoch 37/100
# 207/207 [==============================] - 144s 696ms/step - loss: 0.3896 - accuracy: 0.8462 - false_positive_rate: 0.0078 - recall: 0.7860 - val_loss: 0.2810 - val_accuracy: 0.8992 - val_false_positive_rate: 0.0040 - val_recall: 0.8630
# Epoch 38/100
# 207/207 [==============================] - 144s 695ms/step - loss: 0.3886 - accuracy: 0.8468 - false_positive_rate: 0.0077 - recall: 0.7858 - val_loss: 0.2779 - val_accuracy: 0.8991 - val_false_positive_rate: 0.0041 - val_recall: 0.8629
# Epoch 39/100
# 207/207 [==============================] - 144s 695ms/step - loss: 0.3864 - accuracy: 0.8473 - false_positive_rate: 0.0078 - recall: 0.7877 - val_loss: 0.2826 - val_accuracy: 0.8990 - val_false_positive_rate: 0.0042 - val_recall: 0.8642
# Epoch 40/100
# 207/207 [==============================] - 143s 693ms/step - loss: 0.3858 - accuracy: 0.8476 - false_positive_rate: 0.0076 - recall: 0.7871 - val_loss: 0.2735 - val_accuracy: 0.9008 - val_false_positive_rate: 0.0042 - val_recall: 0.8658
# Epoch 41/100
# 207/207 [==============================] - 143s 693ms/step - loss: 0.3840 - accuracy: 0.8484 - false_positive_rate: 0.0076 - recall: 0.7886 - val_loss: 0.2808 - val_accuracy: 0.9003 - val_false_positive_rate: 0.0048 - val_recall: 0.8665
# Epoch 42/100
# 207/207 [==============================] - 143s 693ms/step - loss: 0.3843 - accuracy: 0.8480 - false_positive_rate: 0.0076 - recall: 0.7877 - val_loss: 0.2751 - val_accuracy: 0.8996 - val_false_positive_rate: 0.0040 - val_recall: 0.8632
# Epoch 43/100
# 207/207 [==============================] - 143s 690ms/step - loss: 0.3820 - accuracy: 0.8488 - false_positive_rate: 0.0077 - recall: 0.7893 - val_loss: 0.2743 - val_accuracy: 0.9005 - val_false_positive_rate: 0.0039 - val_recall: 0.8641
# Epoch 44/100
# 207/207 [==============================] - 143s 690ms/step - loss: 0.3810 - accuracy: 0.8487 - false_positive_rate: 0.0076 - recall: 0.7893 - val_loss: 0.2723 - val_accuracy: 0.9009 - val_false_positive_rate: 0.0044 - val_recall: 0.8667
# Epoch 45/100
# 207/207 [==============================] - 144s 695ms/step - loss: 0.3791 - accuracy: 0.8495 - false_positive_rate: 0.0075 - recall: 0.7899 - val_loss: 0.2751 - val_accuracy: 0.9013 - val_false_positive_rate: 0.0049 - val_recall: 0.8703
# Epoch 46/100
# 207/207 [==============================] - 145s 698ms/step - loss: 0.3780 - accuracy: 0.8501 - false_positive_rate: 0.0075 - recall: 0.7905 - val_loss: 0.2819 - val_accuracy: 0.8998 - val_false_positive_rate: 0.0046 - val_recall: 0.8647
# Epoch 47/100
# 207/207 [==============================] - 144s 695ms/step - loss: 0.3769 - accuracy: 0.8506 - false_positive_rate: 0.0075 - recall: 0.7913 - val_loss: 0.2766 - val_accuracy: 0.8997 - val_false_positive_rate: 0.0042 - val_recall: 0.8644
# Epoch 48/100
# 207/207 [==============================] - 144s 695ms/step - loss: 0.3749 - accuracy: 0.8510 - false_positive_rate: 0.0075 - recall: 0.7922 - val_loss: 0.2839 - val_accuracy: 0.8993 - val_false_positive_rate: 0.0052 - val_recall: 0.8683
# Epoch 49/100
# 207/207 [==============================] - 144s 695ms/step - loss: 0.3764 - accuracy: 0.8508 - false_positive_rate: 0.0075 - recall: 0.7914 - val_loss: 0.2749 - val_accuracy: 0.9021 - val_false_positive_rate: 0.0042 - val_recall: 0.8674
# Epoch 50/100
# 207/207 [==============================] - 143s 690ms/step - loss: 0.3741 - accuracy: 0.8507 - false_positive_rate: 0.0076 - recall: 0.7927 - val_loss: 0.2766 - val_accuracy: 0.9008 - val_false_positive_rate: 0.0048 - val_recall: 0.8675
# Epoch 51/100
# 207/207 [==============================] - 143s 693ms/step - loss: 0.3718 - accuracy: 0.8519 - false_positive_rate: 0.0075 - recall: 0.7941 - val_loss: 0.2815 - val_accuracy: 0.9011 - val_false_positive_rate: 0.0051 - val_recall: 0.8698
# Epoch 52/100
# 207/207 [==============================] - 143s 693ms/step - loss: 0.3711 - accuracy: 0.8524 - false_positive_rate: 0.0073 - recall: 0.7929 - val_loss: 0.2777 - val_accuracy: 0.9020 - val_false_positive_rate: 0.0047 - val_recall: 0.8690
# Epoch 53/100
# 207/207 [==============================] - 143s 692ms/step - loss: 0.3697 - accuracy: 0.8525 - false_positive_rate: 0.0074 - recall: 0.7948 - val_loss: 0.2783 - val_accuracy: 0.9007 - val_false_positive_rate: 0.0045 - val_recall: 0.8660
# Epoch 54/100
# 207/207 [==============================] - 143s 690ms/step - loss: 0.3709 - accuracy: 0.8518 - false_positive_rate: 0.0075 - recall: 0.7949 - val_loss: 0.2771 - val_accuracy: 0.9008 - val_false_positive_rate: 0.0045 - val_recall: 0.8650
# Epoch 55/100
# 207/207 [==============================] - 143s 693ms/step - loss: 0.3683 - accuracy: 0.8531 - false_positive_rate: 0.0074 - recall: 0.7954 - val_loss: 0.2828 - val_accuracy: 0.9012 - val_false_positive_rate: 0.0047 - val_recall: 0.8674
# Epoch 56/100
# 207/207 [==============================] - 144s 693ms/step - loss: 0.3675 - accuracy: 0.8530 - false_positive_rate: 0.0074 - recall: 0.7955 - val_loss: 0.2814 - val_accuracy: 0.9016 - val_false_positive_rate: 0.0042 - val_recall: 0.8659
# Epoch 57/100
# 207/207 [==============================] - 143s 690ms/step - loss: 0.3660 - accuracy: 0.8545 - false_positive_rate: 0.0072 - recall: 0.7961 - val_loss: 0.2725 - val_accuracy: 0.9029 - val_false_positive_rate: 0.0050 - val_recall: 0.8716
# Epoch 58/100
# 207/207 [==============================] - 143s 692ms/step - loss: 0.3658 - accuracy: 0.8534 - false_positive_rate: 0.0074 - recall: 0.7959 - val_loss: 0.2745 - val_accuracy: 0.9030 - val_false_positive_rate: 0.0050 - val_recall: 0.8725
# Epoch 59/100
# 207/207 [==============================] - 143s 690ms/step - loss: 0.3654 - accuracy: 0.8543 - false_positive_rate: 0.0073 - recall: 0.7964 - val_loss: 0.2797 - val_accuracy: 0.9016 - val_false_positive_rate: 0.0058 - val_recall: 0.8741
# Epoch 60/100
# 207/207 [==============================] - 143s 691ms/step - loss: 0.3625 - accuracy: 0.8551 - false_positive_rate: 0.0073 - recall: 0.7985 - val_loss: 0.2792 - val_accuracy: 0.9011 - val_false_positive_rate: 0.0054 - val_recall: 0.8715
# Epoch 61/100
# 207/207 [==============================] - 143s 691ms/step - loss: 0.3623 - accuracy: 0.8557 - false_positive_rate: 0.0073 - recall: 0.7982 - val_loss: 0.2868 - val_accuracy: 0.9011 - val_false_positive_rate: 0.0056 - val_recall: 0.8723
# Epoch 62/100
# 207/207 [==============================] - 143s 690ms/step - loss: 0.3625 - accuracy: 0.8548 - false_positive_rate: 0.0074 - recall: 0.7989 - val_loss: 0.2870 - val_accuracy: 0.9000 - val_false_positive_rate: 0.0055 - val_recall: 0.8718
# Epoch 63/100
# 207/207 [==============================] - 143s 692ms/step - loss: 0.3631 - accuracy: 0.8546 - false_positive_rate: 0.0074 - recall: 0.7975 - val_loss: 0.2878 - val_accuracy: 0.8986 - val_false_positive_rate: 0.0064 - val_recall: 0.8717
# Epoch 64/100
# 207/207 [==============================] - 144s 695ms/step - loss: 0.3586 - accuracy: 0.8566 - false_positive_rate: 0.0071 - recall: 0.7993 - val_loss: 0.2786 - val_accuracy: 0.9016 - val_false_positive_rate: 0.0045 - val_recall: 0.8680
# Epoch 65/100
# 207/207 [==============================] - 144s 694ms/step - loss: 0.3586 - accuracy: 0.8563 - false_positive_rate: 0.0072 - recall: 0.8000 - val_loss: 0.2813 - val_accuracy: 0.9010 - val_false_positive_rate: 0.0054 - val_recall: 0.8708
# Epoch 66/100
# 207/207 [==============================] - 144s 696ms/step - loss: 0.3581 - accuracy: 0.8570 - false_positive_rate: 0.0072 - recall: 0.8012 - val_loss: 0.2880 - val_accuracy: 0.9000 - val_false_positive_rate: 0.0059 - val_recall: 0.8717
# Epoch 67/100
# 207/207 [==============================] - 143s 691ms/step - loss: 0.3571 - accuracy: 0.8561 - false_positive_rate: 0.0072 - recall: 0.7998 - val_loss: 0.2877 - val_accuracy: 0.9000 - val_false_positive_rate: 0.0045 - val_recall: 0.8653
# Epoch 68/100
# 207/207 [==============================] - 143s 691ms/step - loss: 0.3577 - accuracy: 0.8568 - false_positive_rate: 0.0073 - recall: 0.8001 - val_loss: 0.2956 - val_accuracy: 0.8990 - val_false_positive_rate: 0.0056 - val_recall: 0.8704
# Epoch 69/100
# 207/207 [==============================] - 143s 690ms/step - loss: 0.3562 - accuracy: 0.8576 - false_positive_rate: 0.0071 - recall: 0.8004 - val_loss: 0.2927 - val_accuracy: 0.9001 - val_false_positive_rate: 0.0061 - val_recall: 0.8741
# Epoch 70/100
# 207/207 [==============================] - 143s 691ms/step - loss: 0.3547 - accuracy: 0.8580 - false_positive_rate: 0.0072 - recall: 0.8021 - val_loss: 0.2804 - val_accuracy: 0.9002 - val_false_positive_rate: 0.0052 - val_recall: 0.8698
# Epoch 71/100
# 207/207 [==============================] - 151s 732ms/step - loss: 0.3539 - accuracy: 0.8577 - false_positive_rate: 0.0071 - recall: 0.8017 - val_loss: 0.2871 - val_accuracy: 0.8998 - val_false_positive_rate: 0.0062 - val_recall: 0.8739
# Epoch 72/100
# 207/207 [==============================] - 147s 712ms/step - loss: 0.3534 - accuracy: 0.8579 - false_positive_rate: 0.0071 - recall: 0.8015 - val_loss: 0.2865 - val_accuracy: 0.9014 - val_false_positive_rate: 0.0055 - val_recall: 0.8725
# Epoch 73/100
# 207/207 [==============================] - 144s 694ms/step - loss: 0.3525 - accuracy: 0.8581 - false_positive_rate: 0.0072 - recall: 0.8034 - val_loss: 0.2848 - val_accuracy: 0.9007 - val_false_positive_rate: 0.0050 - val_recall: 0.8700
# Epoch 74/100
# 207/207 [==============================] - 143s 691ms/step - loss: 0.3522 - accuracy: 0.8585 - false_positive_rate: 0.0070 - recall: 0.8025 - val_loss: 0.2892 - val_accuracy: 0.9012 - val_false_positive_rate: 0.0055 - val_recall: 0.8720
# Epoch 75/100
# 207/207 [==============================] - 143s 690ms/step - loss: 0.3507 - accuracy: 0.8593 - false_positive_rate: 0.0071 - recall: 0.8040 - val_loss: 0.2950 - val_accuracy: 0.8978 - val_false_positive_rate: 0.0052 - val_recall: 0.8663
# Epoch 76/100
# 207/207 [==============================] - 143s 692ms/step - loss: 0.3509 - accuracy: 0.8589 - false_positive_rate: 0.0070 - recall: 0.8023 - val_loss: 0.2834 - val_accuracy: 0.9009 - val_false_positive_rate: 0.0046 - val_recall: 0.8670
# Epoch 77/100
# 207/207 [==============================] - 143s 693ms/step - loss: 0.3501 - accuracy: 0.8593 - false_positive_rate: 0.0071 - recall: 0.8043 - val_loss: 0.2876 - val_accuracy: 0.9008 - val_false_positive_rate: 0.0053 - val_recall: 0.8702
# Epoch 78/100
# 207/207 [==============================] - 143s 690ms/step - loss: 0.3494 - accuracy: 0.8596 - false_positive_rate: 0.0071 - recall: 0.8048 - val_loss: 0.2957 - val_accuracy: 0.8966 - val_false_positive_rate: 0.0054 - val_recall: 0.8648
# Epoch 79/100
# 207/207 [==============================] - 143s 690ms/step - loss: 0.3491 - accuracy: 0.8599 - false_positive_rate: 0.0071 - recall: 0.8043 - val_loss: 0.2927 - val_accuracy: 0.8988 - val_false_positive_rate: 0.0050 - val_recall: 0.8659
# Epoch 80/100
# 207/207 [==============================] - 143s 690ms/step - loss: 0.3469 - accuracy: 0.8602 - false_positive_rate: 0.0071 - recall: 0.8053 - val_loss: 0.2954 - val_accuracy: 0.8963 - val_false_positive_rate: 0.0053 - val_recall: 0.8650
# Epoch 81/100
# 207/207 [==============================] - 143s 691ms/step - loss: 0.3469 - accuracy: 0.8603 - false_positive_rate: 0.0070 - recall: 0.8043 - val_loss: 0.3010 - val_accuracy: 0.8970 - val_false_positive_rate: 0.0053 - val_recall: 0.8649
# Epoch 82/100
# 207/207 [==============================] - 143s 689ms/step - loss: 0.3466 - accuracy: 0.8605 - false_positive_rate: 0.0071 - recall: 0.8058 - val_loss: 0.3061 - val_accuracy: 0.8964 - val_false_positive_rate: 0.0060 - val_recall: 0.8661
# Epoch 83/100
# 207/207 [==============================] - 143s 690ms/step - loss: 0.3449 - accuracy: 0.8610 - false_positive_rate: 0.0068 - recall: 0.8054 - val_loss: 0.2957 - val_accuracy: 0.8982 - val_false_positive_rate: 0.0061 - val_recall: 0.8713
# Epoch 84/100
# 207/207 [==============================] - 149s 722ms/step - loss: 0.3436 - accuracy: 0.8610 - false_positive_rate: 0.0070 - recall: 0.8071 - val_loss: 0.3007 - val_accuracy: 0.9001 - val_false_positive_rate: 0.0064 - val_recall: 0.8753
# Epoch 85/100
# 207/207 [==============================] - 146s 704ms/step - loss: 0.3460 - accuracy: 0.8602 - false_positive_rate: 0.0070 - recall: 0.8057 - val_loss: 0.3028 - val_accuracy: 0.8987 - val_false_positive_rate: 0.0074 - val_recall: 0.8768
# Epoch 86/100
# 207/207 [==============================] - 144s 694ms/step - loss: 0.3448 - accuracy: 0.8611 - false_positive_rate: 0.0071 - recall: 0.8075 - val_loss: 0.3025 - val_accuracy: 0.9010 - val_false_positive_rate: 0.0061 - val_recall: 0.8747
# Epoch 87/100
# 207/207 [==============================] - 144s 695ms/step - loss: 0.3446 - accuracy: 0.8612 - false_positive_rate: 0.0069 - recall: 0.8051 - val_loss: 0.3009 - val_accuracy: 0.9002 - val_false_positive_rate: 0.0064 - val_recall: 0.8760
# Epoch 88/100
# 207/207 [==============================] - 149s 720ms/step - loss: 0.3428 - accuracy: 0.8620 - false_positive_rate: 0.0070 - recall: 0.8087 - val_loss: 0.2938 - val_accuracy: 0.9018 - val_false_positive_rate: 0.0053 - val_recall: 0.8711
# Epoch 89/100
# 207/207 [==============================] - 150s 725ms/step - loss: 0.3420 - accuracy: 0.8619 - false_positive_rate: 0.0069 - recall: 0.8071 - val_loss: 0.3014 - val_accuracy: 0.8992 - val_false_positive_rate: 0.0056 - val_recall: 0.8696
# Epoch 90/100
# 207/207 [==============================] - 150s 725ms/step - loss: 0.3423 - accuracy: 0.8621 - false_positive_rate: 0.0069 - recall: 0.8071 - val_loss: 0.2986 - val_accuracy: 0.9008 - val_false_positive_rate: 0.0062 - val_recall: 0.8753
# Epoch 91/100
# 207/207 [==============================] - 150s 723ms/step - loss: 0.3415 - accuracy: 0.8615 - false_positive_rate: 0.0070 - recall: 0.8075 - val_loss: 0.2990 - val_accuracy: 0.9000 - val_false_positive_rate: 0.0063 - val_recall: 0.8741
# Epoch 92/100
# 207/207 [==============================] - 150s 727ms/step - loss: 0.3392 - accuracy: 0.8630 - false_positive_rate: 0.0068 - recall: 0.8078 - val_loss: 0.2999 - val_accuracy: 0.9006 - val_false_positive_rate: 0.0065 - val_recall: 0.8764
# Epoch 93/100
# 207/207 [==============================] - 151s 731ms/step - loss: 0.3401 - accuracy: 0.8626 - false_positive_rate: 0.0069 - recall: 0.8082 - val_loss: 0.3000 - val_accuracy: 0.8991 - val_false_positive_rate: 0.0061 - val_recall: 0.8725
# Epoch 94/100
# 207/207 [==============================] - 151s 730ms/step - loss: 0.3394 - accuracy: 0.8627 - false_positive_rate: 0.0069 - recall: 0.8090 - val_loss: 0.2964 - val_accuracy: 0.9005 - val_false_positive_rate: 0.0053 - val_recall: 0.8714
# Epoch 95/100
# 207/207 [==============================] - 151s 727ms/step - loss: 0.3379 - accuracy: 0.8634 - false_positive_rate: 0.0068 - recall: 0.8096 - val_loss: 0.3196 - val_accuracy: 0.8955 - val_false_positive_rate: 0.0082 - val_recall: 0.8774
# Epoch 96/100
# 207/207 [==============================] - 151s 729ms/step - loss: 0.3376 - accuracy: 0.8635 - false_positive_rate: 0.0068 - recall: 0.8099 - val_loss: 0.3082 - val_accuracy: 0.8983 - val_false_positive_rate: 0.0072 - val_recall: 0.8767
# Epoch 97/100
# 207/207 [==============================] - 153s 739ms/step - loss: 0.3361 - accuracy: 0.8638 - false_positive_rate: 0.0068 - recall: 0.8103 - val_loss: 0.3036 - val_accuracy: 0.8999 - val_false_positive_rate: 0.0056 - val_recall: 0.8707
# Epoch 98/100
# 207/207 [==============================] - 151s 730ms/step - loss: 0.3376 - accuracy: 0.8631 - false_positive_rate: 0.0068 - recall: 0.8085 - val_loss: 0.3119 - val_accuracy: 0.8976 - val_false_positive_rate: 0.0066 - val_recall: 0.8735
# Epoch 99/100
# 207/207 [==============================] - 151s 730ms/step - loss: 0.3367 - accuracy: 0.8642 - false_positive_rate: 0.0068 - recall: 0.8100 - val_loss: 0.3127 - val_accuracy: 0.8989 - val_false_positive_rate: 0.0069 - val_recall: 0.8765
# Epoch 100/100
# 207/207 [==============================] - 151s 730ms/step - loss: 0.3359 - accuracy: 0.8645 - false_positive_rate: 0.0067 - recall: 0.8097 - val_loss: 0.3085 - val_accuracy: 0.8992 - val_false_positive_rate: 0.0053 - val_recall: 0.8680

# %%
test_results1 = model.evaluate(X_test, Y_test, verbose=1)
print(f'Test results1 -  Accuracy: {test_results1[1]*100}')
# Out:
# 1611/1611 [==============================] - 18s 11ms/step - loss: 0.3114 - accuracy: 0.8771 - false_positive_rate: 0.0057 - recall: 0.8290
# Test results1 -  Accuracy: 87.71320581436157

# %%
print("MODEL - 1")
plot_loss(history)
plot_train_history(history)
# Out:
# MODEL - 1
